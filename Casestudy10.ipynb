# %% [markdown]
# Case Study on Correlation and Regression
# A textile company regularly spent money on five advertising companies for their
# ads. (Dataset added along with)
# 1. First of all, check whether there is any relationship between the amount
# spent for advertising through five different companies and profit
# generated.
# 2. Build a regression model to predict the profit from the given data and
# comment your findings on it.
# 3. Predict the profit generated by the company, if they wish to spend the
# following amount for advertisement.
#
#
#
# | --- | --- | --- |
# |Add1(in Thousands)|290|
# | --- | --- | --- |
# |Add2(in Thousands)|312|
# | --- | --- | --- |
# |Add3(in Thousands) 309|
# | --- | --- | --- |
# |Add4(in Thousands) 298|
# | --- | --- | --- |
# |Add5(in Thousands) 320|

# %%
# !pip uninstall matplotlib
# !pip install -U matplotlib
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\akhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\akhil\anaconda3\lib\site-packages)
# WARNING: Skipping matplotlib as it is not installed.
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\akhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\akhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\akhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\akhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\akhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\akhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\akhil\anaconda3\lib\site-packages)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'D:\Devi\ICT_TVM\CASE STUDY\New folder\Add_sales_data_2018.csv')

# %%
data.head()
# Out:
#          Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0  2018-10-08              208.00              222.25              206.85
# 1  2018-10-05              217.00              218.60              205.90
# 2  2018-10-04              223.50              227.80              216.15
# 3  2018-10-03              230.00              237.50              225.75
# 4  2018-10-01              234.55              234.60              221.05
#
#    Add4(in Thousands)  Add5(in Thousands)  Profit(in Thousands)
# 0              216.00              215.15              4093.065
# 1              210.25              209.20              4042.448
# 2              217.25              218.20              4213.819
# 3              226.45              227.60              4391.665
# 4              230.30              230.90              4350.683

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  205 non-null    object
#  1   Add1(in Thousands)    205 non-null    float64
#  2   Add2(in Thousands)    205 non-null    float64
#  3   Add3(in Thousands)    205 non-null    float64
#  4   Add4(in Thousands)    205 non-null    float64
#  5   Add5(in Thousands)    205 non-null    float64
#  6   Profit(in Thousands)  205 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 11.3+ KB

# %%
data.dtypes
# Out:
# Date                     object
# Add1(in Thousands)      float64
# Add2(in Thousands)      float64
# Add3(in Thousands)      float64
# Add4(in Thousands)      float64
# Add5(in Thousands)      float64
# Profit(in Thousands)    float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Date                    0
# Add1(in Thousands)      0
# Add2(in Thousands)      0
# Add3(in Thousands)      0
# Add4(in Thousands)      0
# Add5(in Thousands)      0
# Profit(in Thousands)    0
# dtype: int64

# %%
data.shape
# Out:
# (205, 7)

# %%
data.columns
# Out:
# Index(['Date', 'Add1(in Thousands)', 'Add2(in Thousands)',
#        'Add3(in Thousands)', 'Add4(in Thousands)', 'Add5(in Thousands)',
#        'Profit(in Thousands)'],
#       dtype='object')

# %%
freqgraph = data.select_dtypes(include = ['float64'])
freqgraph.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# ### 1.First of all, check whether there is any relationship between the amount spent for advertising through five different companies and profit generated.

# %%
sns.scatterplot(data=data, x=data['Add1(in Thousands)'], y=data['Profit(in Thousands)'])
# Out:
# <AxesSubplot:xlabel='Add1(in Thousands)', ylabel='Profit(in Thousands)'>

# %%
sns.scatterplot(data=data, x=data['Add2(in Thousands)'], y=data['Profit(in Thousands)'])
# Out:
# <AxesSubplot:xlabel='Add2(in Thousands)', ylabel='Profit(in Thousands)'>

# %%
sns.scatterplot(data=data, x=data['Add3(in Thousands)'], y=data['Profit(in Thousands)'])
# Out:
# <AxesSubplot:xlabel='Add3(in Thousands)', ylabel='Profit(in Thousands)'>

# %%
sns.scatterplot(data=data, x=data['Add4(in Thousands)'], y=data['Profit(in Thousands)'])
# Out:
# <AxesSubplot:xlabel='Add4(in Thousands)', ylabel='Profit(in Thousands)'>

# %%
sns.scatterplot(data=data, x=data['Add5(in Thousands)'], y=data['Profit(in Thousands)'])
# Out:
# <AxesSubplot:xlabel='Add5(in Thousands)', ylabel='Profit(in Thousands)'>

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(10,8))
sns.heatmap(corrmatrix, vmin=-.7,vmax=.7,linewidths=.2,annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
corrmatrix
# Out:
#                       Add1(in Thousands)  Add2(in Thousands)  \
# Add1(in Thousands)              1.000000            0.990976
# Add2(in Thousands)              0.990976            1.000000
# Add3(in Thousands)              0.986274            0.987990
# Add4(in Thousands)              0.976365            0.989921
# Add5(in Thousands)              0.976716            0.990285
# Profit(in Thousands)            0.991975            0.999145
#
#                       Add3(in Thousands)  Add4(in Thousands)  \
# Add1(in Thousands)              0.986274            0.976365
# Add2(in Thousands)              0.987990            0.989921
# Add3(in Thousands)              1.000000            0.991343
# Add4(in Thousands)              0.991343            1.000000
# Add5(in Thousands)              0.991908            0.999699
# Profit(in Thousands)            0.993389            0.993346
#
#                       Add5(in Thousands)  Profit(in Thousands)
# ...

# %% [markdown]
# The data follows a trend, as the money spent for add increases, the profit also increases, ie it is proportional to each other. They are highly correlated to ecah other

# %% [markdown]
# ### 2.Build a regression model to predict the profit from the given data and comment your findings on it.

# %%
#  first we have to check for outliers

# %%
sns.boxplot(data=data)
plt.xticks(rotation=90)
plt.xlabel('Money spent for add')
# Out:
# Text(0.5, 0, 'Money spent for add')

# %% [markdown]
# There is no outliers in this dataset

# %%
# splitting the data
X=data.drop(['Profit(in Thousands)','Date'],axis=1)
Y=data['Profit(in Thousands)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=45,test_size=.25)

# %%
from sklearn import linear_model

lr=linear_model.LinearRegression()

# %%
model = lr.fit(X_train,Y_train)
predictions = model.predict(X_test)

# %%
print(predictions)
# Out:
# [5190.758 5239.06  5728.804 4890.723 4436.321 4434.805 5013.207 4980.446
#  4391.665 4925.861 5051.755 5133.766 4922.845 5017.503 5767.839 5861.83
#  5397.739 4907.56  4648.627 5577.15  5001.615 5043.705 4606.34  5378.379
#  5452.28  4411.775 5167.878 5903.253 4513.6   4451.999 5212.949 5146.949
#  4093.065 5113.337 5745.806 5234.487 4419.421 5247.011 4486.996 5962.336
#  5805.521 4350.683 4416.136 5131.898 5425.19  5078.636 5784.54  5030.451
#  6137.8   5088.455 4836.837 4482.183]

# %%
print(Y_test)
# Out:
# 148    5190.758
# 64     5239.060
# 170    5728.804
# 72     4890.723
# 25     4436.321
# 13     4434.805
# 79     5013.207
# 83     4980.446
# 3      4391.665
# 84     4925.861
# 137    5051.755
# 58     5133.766
# 130    4922.845
# 154    5017.503
# 192    5767.839
# 186    5861.830
# 115    5397.739
# 132    4907.560
# 44     4648.627
# 109    5577.150
# 67     5001.615
# 80     5043.705
# 45     4606.340
# 114    5378.379
# 107    5452.280
# 10     4411.775
# 122    5167.878
# 185    5903.253
# 33     4513.600
# 26     4451.999
# 161    5212.949
# 151    5146.949
# 0      4093.065
# 74     5113.337
# 193    5745.806
# 62     5234.487
# 35     4419.421
# 138    5247.011
# 40     4486.996
# 184    5962.336
# 173    5805.521
# 4      4350.683
# 28     4416.136
# 100    5131.898
# 112    5425.190
# 155    5078.636
# 175    5784.540
# 69     5030.451
# 179    6137.800
# 61     5088.455
# 91     4836.837
# 29     4482.183
# Name: Profit(in Thousands), dtype: float64

# %%
from sklearn.metrics import mean_squared_error

print("MSE:", mean_squared_error(Y_test,predictions))
# Out:
# MSE: 3.06215899839342e-25

# %% [markdown]
# ### 4.Predict the profit generated by the company, if they wish to spend the following amount for advertisement.

# %% [markdown]
#  Add1(in Thousands)|290|<br>Add2(in Thousands)|312|<br>Add3(in Thousands) |309|<br>Add4(in Thousands) |298|<br>Add5(in Thousands) |320|<br>

# %%
model.predict([[290,312,309,298,320]])
# Out:
# C:\Users\Akhil\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5820.06])

# %% [markdown]
# For the given values add1 - 290, add2-312, add3-309, add4-298, add5-320, Using our model,the predicted the value of profit ie 5820.06 (in thousands)
